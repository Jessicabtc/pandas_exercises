# %%
import pandas as pd
import numpy as np

# %%
data = pd.Series([1,2,3,4],index = ['a','b','c','d'])

# %%
data
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
df = pd.DataFrame(np.random.randn(5,4),
                  index = ['a','b','c','d','e'],  
                  columns = 'one two three four'.split())

# %%
df
# Out:
#         one       two     three      four
# a -0.968489  1.597468 -0.083334  1.593086
# b  0.978623  0.370262 -0.821822 -0.473772
# c  0.560392  1.874293 -2.282689 -0.891116
# d  1.273179 -0.196113  1.530212 -1.144468
# e -0.823759 -0.339804  0.136591 -0.203373

# %%
df.dtypes
# Out:
# one      float64
# two      float64
# three    float64
# four     float64
# dtype: object

# %%
df.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
df.index.is_unique
# Out:
# True

# %%
txt = "   Hello, welcome to my world."
x = txt.startswith("Hello")

# %%
txt[1]
# Out:
# ' '

# %%
txt[2:3] #include 2 not include 3
txt.upper()
txt.lower()
txt.strip() #strip() removes whitespace from the beginning or the end
txt.replace('Hello', 'Hi')
txt.split(",")
# Out:
# ['   Hello', ' welcome to my world.']

# %%
txt
# Out:
# '   Hello, welcome to my world.'

# %%
txt[:5]
# Out:
# 'Hello'

# %%
len(txt)
# Out:
# 27

# %%
"Hello" in txt
# Out:
# True

# %%
# put an f in front of the string literal, 
# and add curly brackets {} as placeholders for variables and other operations.
age = 9
txt = f"my name is tom, I am {age}"
txt
# Out:
# 'my name is tom I am 9'

# %%
# A modifier is included by adding a colon : followed by a legal formatting type, 
# like .2f which means fixed point number with 2 decimals:
price = 59
txt = f"The price is {price:.2f} dollars"
print(txt)

# %%
print("Hello World")a
# Out:
# Hello World

# %%
if (7>3):
    print("hello 7")
# Out:
# hello 7

# %%
x = float(5)
#int(5)
#str(5)

# %%
type(x)
# Out:
# float

# %%
print("hello", 100, "times")
# Out:
# hello 100 times

# %%
#Python allows you to assign values to multiple variables in one line
x, y, z = 'a','b','c'
print('x=',x, 'y=',y, 'z=',z)
print(x+y+z)
# Out:
# x= a y= b z= c
# abc

# %%
# If you have a collection of values in a list, tuple etc. Python allows you to extract the values into variables. 
# This is called unpacking.

list_a = [1,2,3]
x, y, z = list_a
print('x=',x, 'y=',y, 'z=',z)
print(x+y+z)
# Out:
# x= 1 y= 2 z= 3
# 6

# %%
def myfunc():
    print(x)

# %%
myfunc()
# Out:
# a

# %%
x=range(6)

for i in x:
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
x = {"a": 1, "b":2}
x
# Out:
# {'a': 1, 'b': 2}

# %%
x = dict(a=1, b=2)
x
# Out:
# {'a': 1, 'b': 2}

# %%
import random

i=0

while i < 10:
    print(random.randrange(1,10))
    i+=1
# Out:
# 2
# 5
# 6
# 2
# 4
# 8
# 8
# 3
# 9
# 2

# %%
bool("15")
# Out:
# True

# %%
10%3 #modulus
# Out:
# 1

# %%
10/3 #division (returns a float)
# Out:
# 3.3333333333333335

# %%
10//3 #floor division (returns an integer)
# Out:
# 3

# %%
10**3
# Out:
# 1000

# %%
# Out:
# 9

# %%
x = [1, 2, 3]
y = [1, 2, 3]

print(x == y) #== Checks if the values of both variables are equal
# Out:
# True

# %%
print(x is y) #Checks if both variables point to the same object in memory
# Out:
# False

# %%
type(x)
# Out:
# list

# %%
thislist = ["apple", "banana", "cherry"]
thislist[1:2] = ["blackcurrant", "watermelon"]
print(thislist)
# Out:
# ['apple', 'blackcurrant', 'watermelon', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
thislist.insert(2, "watermelon")
print(thislist)
# Out:
# ['apple', 'banana', 'watermelon', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
thislist.pop(1)
print(thislist)
# Out:
# ['apple', 'cherry']

# %%
for i in range(len(thislist)):
    print(i)
    print(thislist[1])
# Out:
# 0
# cherry
# 1
# cherry

# %%
thislist = ["orange", "mango", "kiwi", "pineapple", "banana"]
thislist.sort(reverse = True) #sort descending
print(thislist)
# Out:
# ['pineapple', 'orange', 'mango', 'kiwi', 'banana']

# %%
thislist.sort()
print(thislist)
# Out:
# ['banana', 'kiwi', 'mango', 'orange', 'pineapple']

# %%
def myfunc(n):
  return abs(n - 50)

thislist = [100, 50, 65, 82, 23]
thislist.sort(key = myfunc)
print(thislist)
# Out:
# [50, 65, 23, 82, 100]

# %%
thatlist = thislist.copy()
thatlist
# Out:
# [50, 65, 23, 82, 100]

# %%
thislist+thatlist
# Out:
# [50, 65, 23, 82, 100, 50, 65, 23, 82, 100]

# %%
thislist.append(thatlist)

# %%
thislist
# Out:
# [50, 65, 23, 82, 100, [50, 65, 23, 82, 100]]

# %%
thislist.count(50)
# Out:
# 1

# %%
mytuple = ("apple", "banana", "cherry")

# %%
mytuple
# Out:
# ('apple', 'banana', 'cherry')

# %%
a = tuple(("haha"))
type(a)
# Out:
# tuple

# %%
# Unpacking
fruits = ("apple", "banana", "cherry")
(green, yellow, red) = fruits
print(green)
# Out:
# apple

# %%
fruits = ("apple", "banana", "cherry", "strawberry", "raspberry")
(green, *yellow, red) = fruits
print(yellow)
# Out:
# ['banana', 'cherry', 'strawberry']

# %%
fruits.index("apple")
# Out:
# 0

# %%
myset = {"apple", "banana", "cherry"}

# %%
myset.add("orange")
myset
# Out:
# {'apple', 'banana', 'cherry', 'orange'}

# %%
thisset = {"apple", "banana", "cherry"}
tropical = {"pineapple", "mango", "papaya"}

thisset.update(tropical)

print(thisset)
# Out:
# {'papaya', 'cherry', 'mango', 'pineapple', 'banana', 'apple'}

# %%
thisset.remove("banana")
print(thisset)
# Out:
# {'papaya', 'cherry', 'mango', 'pineapple', 'apple'}

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}
set3 = {"John", "Elena"}
set4 = {"apple", "bananas", "cherry"}

myset = set1.union(set2, set3, set4)
# or set1 | set2 | set3 | set4
print(myset)
# Out:
# {1, 2, 3, 'cherry', 'b', 'John', 'apple', 'Elena', 'c', 'bananas', 'a'}

# %%
set5 = {"apple", "banana", "cherry"}
set6 = {"google", "microsoft", "apple"}

set7 = set5.intersection(set6)
# or set5 & set6
print(set3)
# Out:
# {'apple'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1.difference(set2)
# or set1-set2

print(set3)
# Out:
# {'cherry', 'banana'}

# %%
thisdict = {
  "car1":{"brand": "Ford",
  "model": "Mustang",
  "year": 1964},
  "car2":{"brand": "BMW",
  "model": "X5",
  "year": 2005}
}

# %%
thisdict
# Out:
# {'car1': {'brand': 'Ford', 'model': 'Mustang', 'year': 1964},
#  'car2': {'brand': 'BMW', 'model': 'X5', 'year': 2005}}

# %%
type(thisdict)
# Out:
# dict

# %%
len(thisdict)
# Out:
# 2

# %%
thisdict['car1']
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
thisdict.keys()
# Out:
# dict_keys(['car1', 'car2'])

# %%
thisdict.values()
# Out:
# dict_values([{'brand': 'Ford', 'model': 'Mustang', 'year': 1964}, {'brand': 'BMW', 'model': 'X5', 'year': 2005}])

# %%
thisdict.items()
# Out:
# dict_items([('car1', {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}), ('car2', {'brand': 'BMW', 'model': 'X5', 'year': 2005})])

# %%
thisdict['car1']['year'] =2025
thisdict
# Out:
# {'car1': {'brand': 'Ford', 'model': 'Mustang', 'year': 2025},
#  'car2': {'brand': 'BMW', 'model': 'X5', 'year': 2005}}

# %%
thisdict['car3'] = {"brand": "tesla",
  "model": "x4",
  "year": 2022}

# %%
thisdict
# Out:
# {'car1': {'brand': 'Ford', 'model': 'Mustang', 'year': 2025},
#  'car2': {'brand': 'BMW', 'model': 'X5', 'year': 2005},
#  'car3': {'brand': 'tesla', 'model': 'x4', 'year': 2022}}

# %%
thisdict.pop("car1")
thisdict
# Out:
# {'car2': {'brand': 'BMW', 'model': 'X5', 'year': 2005},
#  'car3': {'brand': 'tesla', 'model': 'x4', 'year': 2022}}

# %%
#print keys
for x in thisdict:
  print(x)
# Out:
# car2
# car3

# %%
#print values
for x in thisdict:
  print(thisdict[x])
# Out:
# {'brand': 'BMW', 'model': 'X5', 'year': 2005}
# {'brand': 'tesla', 'model': 'x4', 'year': 2022}

# %%
for x, y in thisdict.items():
  print(x, y)
# Out:
# car2 {'brand': 'BMW', 'model': 'X5', 'year': 2005}
# car3 {'brand': 'tesla', 'model': 'x4', 'year': 2022}

# %%
#You cannot copy a dictionary simply by typing dict2 = dict1, 
# because: dict2 will only be a reference to dict1, 
# and changes made in dict1 will automatically also be made in dict2.
mydict = thisdict.copy()
print(mydict)

# %%
score = 38

if score >= 90:
  print("Grade: A")
elif score >= 80:
  print("Grade: B")
elif score >= 70:
  print("Grade: C")
elif score >= 60:
  print("Grade: D")
else:
   print("Failed")
# Out:
# Failed

# %%
# nested if
x = 41

if x > 10:
  print("Above ten,")
  if x > 20:
    print("and also above 20!")
  else:
    print("but not above 20.")
# Out:
# Above ten,
# and also above 20!

# %%
score = 85
attendance = 75
submitted = True

if score >= 60:
  if attendance >= 80:
    if submitted:
      print("Pass with good standing")
    else:
      print("Pass but missing assignment")
  else:
    print("Pass but low attendance")
else:
  print("Fail")
# Out:
# Pass but low attendance

# %%
# if statements cannot be empty, but 
# if you for some reason have an if statement with no content,
#  put in the pass statement to avoid getting an error.

age = 16

if age < 18:
  pass # TODO: Add underage logic later
else:
  print("Access granted")

# %%
#Pass is also commonly used with loops, functions, and classes.
def calculate_discount(price):
  pass # TODO: Implement discount logic

# Function exists but doesn't do anything yet

# %%
month = 5
day = 8
match day:
  case 1 | 2 | 3 | 4 | 5 if month == 4:
    print("A weekday in April")
  case 1 | 2 | 3 | 4 | 5 if month == 5:
    print("A weekday in May")
  case _:
    print("No match")
# Out:
# No match

# %%
i = 1
while i < 6:
  print(i)
  if i == 3:
    break
  i += 1
# Out:
# 1
# 2
# 3

# %%
i = 0
while i < 6:
  i += 1
  if i == 3:
    continue
  print(i)
# Out:
# 1
# 2
# 4
# 5
# 6

# %%
i = 1
while i < 6:
  print(i)
  i += 1
else:
  print("i is no longer less than 6")
# Out:
# 1
# 2
# 3
# 4
# 5
# i is no longer less than 6

# %%
for x in range(3, 30, 3): #not include 30
  print(x)
# Out:
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27

# %%
def f_to_c(t_in_f):
    t_in_c = (t_in_f -32) * 5 /9
    return(t_in_c)

f_to_c(70)
# Out:
# 21.11111111111111

# %%
#Decorators let you add extra behavior to a function, 
# without changing the function's code.
# A decorator is a function that takes another function as input and returns a new function
def changecase(func):
  def myinner():
    return func().upper()
  return myinner

@changecase
def myfunction():
  return "Hello Sally"

print(myfunction())
# Out:
# HELLO SALLY

# %%
# function's name can be returned with the __name__ attribute
def myfunction():
  return "Have a great day!"

print(myfunction.__name__)
# Out:
# myfunction

# %%
def changecase(func):
  def myinner():
    return func().upper()
  return myinner

@changecase
def myfunction():
  return "Have a great day!"

print(myfunction.__name__)
# Out:
# myinner

# %%
x = lambda a, b, c : a + b + c
print(x(5, 6, 2))
# Out:
# 13

# %%
def myfunc(n):
  return lambda a : a * n

mydoubler = myfunc(3)

print(mydoubler(11))
# Out:
# 33

# %%
#The map() function applies a function to every item in an iterable
numbers = [1, 2, 3, 4, 5]
doubled = list(map(lambda x: x * 2, numbers))
print(doubled)
# Out:
# [2, 4, 6, 8, 10]

# %%
#The filter() function creates a list of items for which a function returns True
numbers = [1, 2, 3, 4, 5, 6, 7, 8]
odd_numbers = list(filter(lambda x: x % 2 != 0, numbers))
print(odd_numbers)
# Out:
# [1, 3, 5, 7]

# %%
#The sorted() function can use a lambda as a key for custom sorting:
students = [("Emil", 25), ("Tobias", 22), ("Linus", 28)]
sorted_students = sorted(students, key=lambda x: x[1])
print(sorted_students)
